# %%
stateful_name="state0"

# %%
stateful_name="should_not_see_this_state"

# %%
def hello(name=None):
    return "Hello {0}".format(name or stateful_name)

# %%
hello()
stateful_name = "state1"

# %%
hello()
hello()
# Out:
# 'Hello state1'

# %%
hello("functional_name")
# Out:
# 'Hello functional_name'

# %%
# %matplotlib inline


import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)
r = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, s=np.pi*r**2*100, c='blue', alpha=0.75)

plt.show()
